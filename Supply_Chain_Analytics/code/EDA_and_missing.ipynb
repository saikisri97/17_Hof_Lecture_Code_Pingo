# %%
#importing the data

import pandas as pd
url =  "https://raw.githubusercontent.com/saikisri97/17_Hof_Lecture_Code_Pingo/refs/heads/main/Supply_Chain_Analytics/data/Global_Shipments.csv"
df = pd.read_csv(url)
df.head(5)
# Out:
#   Shipment_ID        Week Warehouse_ID Store_ID Carrier Product_Category  \
# 0     SH00000  2024-02-18            C      S07      C3           Frozen
# 1     SH00001  2024-05-19            B      S05      C3          Grocery
# 2     SH00002  2024-04-14            C      S07      C1         Clothing
# 3     SH00003  2024-03-17            B      S03      C3      Electronics
# 4     SH00004  2024-02-25            C      S12      C1          Grocery
#
#    Weight_kg  Delivery_Time_hrs  Fuel_Price_EUR_per_litre  Temperature_C  \
# 0      19.06               29.3                      1.67            2.7
# 1      10.35               30.4                      1.61            2.5
# 2      14.93               34.7                      1.63            NaN
# 3      11.06               29.8                      1.76            NaN
# 4       3.41               27.3                      1.69           -0.7
#
#    Promo_Flag  On_Time_Flag  Weekly_Sales_EUR             Notes
# 0           0             1          64724.47               NaN
# 1           0             1          61723.79               NaN
# 2           1             1          54098.40  Partial delivery
# 3           0             0          60609.65    Damaged carton
# 4           0             0          55689.16               NaN
