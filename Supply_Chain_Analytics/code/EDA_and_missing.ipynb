# %%
#importing the data

import pandas as pd
url =  "https://raw.githubusercontent.com/saikisri97/17_Hof_Lecture_Code_Pingo/Supply_Chain_Analytics/data/Global_Shipments.csv"
df = pd.read_csv(url)
df.head(5)
